# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('../input/Combined-Data-V1/Combined_Data_V1.csv')

# %%
dataset.head()

# %%
import plotly.express as px

fig = px.pie(dataset, values=dataset['AppName'].value_counts().values, names=dataset['AppName'].value_counts().index)
fig.show()

# %%
dataset.pivot_table(values='reviewId',index='Year',columns='AppName',aggfunc='count')
